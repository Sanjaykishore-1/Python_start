# %%
import pandas as pd

# %%
sales_final = pd.read_csv("sales_final.csv")
sales_final
# Out:
#             Date  Voucher               Party              Product  Qty  \
# 0       1/4/2017        1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1       1/4/2017        1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2       1/4/2017        2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3       1/4/2017        2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4       1/4/2017        2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...          ...      ...                 ...                  ...  ...
# 95557  12/9/2019     4265                TP13        SPOON MED M.W   20
# 95558  12/9/2019     4266           K.SRIHARI       SMART BOUL(48)    1
# 95559  12/9/2019     4267                 SMS  SMARTBOUL GLA(4000)    1
# 95560  12/9/2019     4268           ANILFANCY         RR WINEGLASS  100
# 95561  12/9/2019     4268           ANILFANCY       RR WATER GLASS  100
#
#          Rate
# 0      1690.0
# 1      1620.0
# 2        23.0
# 3      1620.0
# 4      1690.0
# ...

# %%
sales_final.dtypes
# Out:
# Date           str
# Voucher      int64
# Party          str
# Product        str
# Qty          int64
# Rate       float64
# dtype: object

# %%
sales_2017 = pd.read_csv("sales_2017.csv")
sales_2018 = pd.read_csv("sales_2018.csv")
sales_2019 = pd.read_csv("sales_2019.csv")

# %%
overral_sales_data = pd.concat(objs=[sales_2017, sales_2018, sales_2019])
overral_sales_data
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
overral_sales_data.drop_duplicates(inplace=True)

# %%
overral_sales_data
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
overral_sales_data['Qty'].convert_dtypes('integer')
# Out:
# 0                   2
# 1                   6
# 2                 500
# 3                   6
# 4                   5
#              ...
# 19169             320
# 19170             800
# 19171             400
# 19174       99,284.90
# 19175    2,710,193.00
# Name: Qty, Length: 96624, dtype: string

# %%
overral_sales_data.isna().sum()
# Out:
# Date                204
# Voucher             170
# Party                35
# Product             204
# Qty                 170
# Rate                171
# Gross               171
# Disc              92951
# Voucher Amount    70984
# dtype: int64

# %%
sales_final.dtypes
# Out:
# Date           str
# Voucher      int64
# Party          str
# Product        str
# Qty          int64
# Rate       float64
# dtype: object

# %%
overral_sales_data.dtypes
# Out:
# Date              str
# Voucher           str
# Party             str
# Product           str
# Qty               str
# Rate              str
# Gross             str
# Disc              str
# Voucher Amount    str
# dtype: object

# %%
overral_sales_data['Voucher'] = overral_sales_data['Voucher'].replace('Sal:','', regex=True)

# %%
overral_sales_data ["Voucher"]= overral_sales_data['Voucher'].convert_dtypes('Int64')

# %%
sales_final
# Out:
#             Date  Voucher               Party              Product  Qty  \
# 0       1/4/2017        1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1       1/4/2017        1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2       1/4/2017        2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3       1/4/2017        2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4       1/4/2017        2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...          ...      ...                 ...                  ...  ...
# 95557  12/9/2019     4265                TP13        SPOON MED M.W   20
# 95558  12/9/2019     4266           K.SRIHARI       SMART BOUL(48)    1
# 95559  12/9/2019     4267                 SMS  SMARTBOUL GLA(4000)    1
# 95560  12/9/2019     4268           ANILFANCY         RR WINEGLASS  100
# 95561  12/9/2019     4268           ANILFANCY       RR WATER GLASS  100
#
#          Rate
# 0      1690.0
# 1      1620.0
# 2        23.0
# 3      1620.0
# 4      1690.0
# ...

# %%
overral_sales_data['Date'] = pd.to_datetime(overral_sales_data["Date"], format="%d/%m/%Y", errors='coerce')

# %%
overral_sales_data["Rate"] = pd.to_numeric(overral_sales_data["Rate"], errors='coerce')

# %%
overral_sales_data['Qty'] = pd.to_numeric(overral_sales_data['Qty'], errors='coerce').convert_dtypes('float64')

# %%
overral_sales_data["Qty"] = overral_sales_data["Qty"].astype('float64')

# %%
overral_sales_data.dtypes
# Out:
# Date           str
# Voucher        str
# Party          str
# Product        str
# Qty            str
# Rate           str
# Gross      float64
# dtype: object

# %%
overral_sales_data
# Out:
#             Date  Voucher               Party            Product    Qty  Rate  \
# 0     2017-04-01        1    SOLANKI PLASTICS      DONA-VAI-9100    2.0   NaN
# 1     2017-04-01        1    SOLANKI PLASTICS    LITE FOAM(1200)    6.0   NaN
# 2     2017-04-01        2  SARNESWARA TRADERS  VISHNU CHOTA WINE  500.0  23.0
# 3     2017-04-01        2  SARNESWARA TRADERS    LITE FOAM(1200)    6.0   NaN
# 4     2017-04-01        2  SARNESWARA TRADERS      DONA-VAI-9100    5.0   NaN
# ...          ...      ...                 ...                ...    ...   ...
# 19171 2019-10-10     4935           K.SRIHARI     13*16 WHITE RK  400.0  16.0
# 19172        NaT     <NA>                 NaN                NaN    NaN   NaN
# 19173        NaT     <NA>                 NaN                NaN    NaN   NaN
# 19174        NaT  Total                   NaN                NaN    NaN   NaN
# 19175        NaT  Total                   NaN                NaN    NaN   NaN
#
# ...

# %%
del overral_sales_data['Disc']

# %%
del overral_sales_data['Voucher Amount']

# %%
overral_sales_data
# Out:
#             Date  Voucher               Party            Product    Qty  Rate  \
# 0     2017-04-01        1    SOLANKI PLASTICS      DONA-VAI-9100    2.0   NaN
# 1     2017-04-01        1    SOLANKI PLASTICS    LITE FOAM(1200)    6.0   NaN
# 2     2017-04-01        2  SARNESWARA TRADERS  VISHNU CHOTA WINE  500.0  23.0
# 3     2017-04-01        2  SARNESWARA TRADERS    LITE FOAM(1200)    6.0   NaN
# 4     2017-04-01        2  SARNESWARA TRADERS      DONA-VAI-9100    5.0   NaN
# ...          ...      ...                 ...                ...    ...   ...
# 19171 2019-10-10     4935           K.SRIHARI     13*16 WHITE RK  400.0  16.0
# 19172        NaT     <NA>                 NaN                NaN    NaN   NaN
# 19173        NaT     <NA>                 NaN                NaN    NaN   NaN
# 19174        NaT  Total                   NaN                NaN    NaN   NaN
# 19175        NaT  Total                   NaN                NaN    NaN   NaN
#
#                Gross
# ...

# %%
overral_sales_data.drop_duplicates()
# Out:
#             Date  Voucher               Party              Product    Qty  \
# 0     2017-04-01        1    SOLANKI PLASTICS        DONA-VAI-9100    2.0
# 1     2017-04-01        1    SOLANKI PLASTICS      LITE FOAM(1200)    6.0
# 2     2017-04-01        2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500.0
# 3     2017-04-01        2  SARNESWARA TRADERS      LITE FOAM(1200)    6.0
# 4     2017-04-01        2  SARNESWARA TRADERS        DONA-VAI-9100    5.0
# ...          ...      ...                 ...                  ...    ...
# 19169 2019-10-10     4935           K.SRIHARI  13*16 Bk(100)KRISHN  320.0
# 19170 2019-10-10     4935           K.SRIHARI             10*12 RK  800.0
# 19171 2019-10-10     4935           K.SRIHARI       13*16 WHITE RK  400.0
# 19174        NaT  Total                   NaN                  NaN    NaN
# 19175        NaT  Total                   NaN                  NaN    NaN
#
#        Rate          Gross
# 0       NaN       3,380.00
# ...

# %%
overral_sales_data.isnull().sum()
# Out:
# Date       15644
# Voucher    12557
# Party         40
# Product    12591
# Qty        19010
# Rate       21454
# Gross      12558
# dtype: int64

# %%
sales_final
# Out:
#             Date  Voucher               Party              Product  Qty  \
# 0       1/4/2017        1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1       1/4/2017        1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2       1/4/2017        2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3       1/4/2017        2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4       1/4/2017        2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...          ...      ...                 ...                  ...  ...
# 95557  12/9/2019     4265                TP13        SPOON MED M.W   20
# 95558  12/9/2019     4266           K.SRIHARI       SMART BOUL(48)    1
# 95559  12/9/2019     4267                 SMS  SMARTBOUL GLA(4000)    1
# 95560  12/9/2019     4268           ANILFANCY         RR WINEGLASS  100
# 95561  12/9/2019     4268           ANILFANCY       RR WATER GLASS  100
#
#          Rate
# 0      1690.0
# 1      1620.0
# 2        23.0
# 3      1620.0
# 4      1690.0
# ...

# %%
overral_sales_data['Gross'] = pd.to_numeric(overral_sales_data['Gross'].astype(str).str.replace(',', ''), errors='coerce')

# %%
overral_sales_data
# Out:
#              Date  Voucher               Party            Product  \
# 0        1/4/2017     <NA>    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     <NA>    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     <NA>  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     <NA>  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     <NA>  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...      ...                 ...                ...
# 19171  10/10/2019     <NA>           K.SRIHARI     13*16 WHITE RK
# 19172         NaN     <NA>                 NaN                NaN
# 19173         NaN     <NA>                 NaN                NaN
# 19174         NaN     <NA>                 NaN                NaN
# 19175         NaN     <NA>                 NaN                NaN
#
#                 Qty          Rate  Gross
# 0                 2      1,690.00    NaN
# 1                 6      1,620.00    NaN
# 2               500            23    NaN
# ...

# %%
overral_sales_data['Rate'] = overral_sales_data['Rate'].fillna(overral_sales_data['Gross'] / overral_sales_data['Qty'], inplace=True)
# Out:
# C:\Users\smanoharan\AppData\Local\Temp\ipykernel_3348\1854703355.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   overral_sales_data['Rate'] = overral_sales_data['Rate'].fillna(overral_sales_data['Gross'] / overral_sales_data['Qty'], inplace=True)

# %%
overral_sales_data.drop_duplicates()
# Out:
#             Date  Voucher               Party              Product    Qty  \
# 0     2017-04-01        1    SOLANKI PLASTICS        DONA-VAI-9100    2.0
# 1     2017-04-01        1    SOLANKI PLASTICS      LITE FOAM(1200)    6.0
# 2     2017-04-01        2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500.0
# 3     2017-04-01        2  SARNESWARA TRADERS      LITE FOAM(1200)    6.0
# 4     2017-04-01        2  SARNESWARA TRADERS        DONA-VAI-9100    5.0
# ...          ...      ...                 ...                  ...    ...
# 19169 2019-10-10     4935           K.SRIHARI  13*16 Bk(100)KRISHN  320.0
# 19170 2019-10-10     4935           K.SRIHARI             10*12 RK  800.0
# 19171 2019-10-10     4935           K.SRIHARI       13*16 WHITE RK  400.0
# 19174        NaT  Total                   NaN                  NaN    NaN
# 19175        NaT  Total                   NaN                  NaN    NaN
#
#          Rate       Gross
# 0      1690.0      3380.0
# ...

# %%
overral_sales_data.dropna()
# Out:
#             Date Voucher               Party              Product    Qty  \
# 0     2017-04-01       1    SOLANKI PLASTICS        DONA-VAI-9100    2.0
# 1     2017-04-01       1    SOLANKI PLASTICS      LITE FOAM(1200)    6.0
# 2     2017-04-01       2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500.0
# 3     2017-04-01       2  SARNESWARA TRADERS      LITE FOAM(1200)    6.0
# 4     2017-04-01       2  SARNESWARA TRADERS        DONA-VAI-9100    5.0
# ...          ...     ...                 ...                  ...    ...
# 19167 2019-10-10    4935           K.SRIHARI         16*20(100-W)  140.0
# 19168 2019-10-10    4935           K.SRIHARI  10*12 KRISHNA-BK(10  600.0
# 19169 2019-10-10    4935           K.SRIHARI  13*16 Bk(100)KRISHN  320.0
# 19170 2019-10-10    4935           K.SRIHARI             10*12 RK  800.0
# 19171 2019-10-10    4935           K.SRIHARI       13*16 WHITE RK  400.0
#
#          Rate    Gross
# 0      1690.0   3380.0
# 1      1620.0   9720.0
# ...

# %%
overral_sales_data["Voucher"] = overral_sales_data["Voucher"].str.replace('',"")

# %%
overral_sales_data['Voucher'] = pd.to_numeric(overral_sales_data['Voucher'], errors='coerce').convert_dtypes('Int64')

# %%
del overral_sales_data['Gross']

# %%
overral_sales_data
# Out:
#             Date  Voucher               Party              Product  Qty  \
# 0     2017-04-01        1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1     2017-04-01        1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2     2017-04-01        2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3     2017-04-01        2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4     2017-04-01        2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...          ...      ...                 ...                  ...  ...
# 19167 2019-10-10     4935           K.SRIHARI         16*20(100-W)  140
# 19168 2019-10-10     4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 19169 2019-10-10     4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 19170 2019-10-10     4935           K.SRIHARI             10*12 RK  800
# 19171 2019-10-10     4935           K.SRIHARI       13*16 WHITE RK  400
#
#          Rate
# 0      1690.0
# 1      1620.0
# 2        23.0
# 3      1620.0
# 4      1690.0
# ...

# %%
overral_sales_data.dropna(inplace = True)

# %%
sales_final
# Out:
#             Date  Voucher               Party              Product  Qty  \
# 0       1/4/2017        1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1       1/4/2017        1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2       1/4/2017        2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3       1/4/2017        2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4       1/4/2017        2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...          ...      ...                 ...                  ...  ...
# 95557  12/9/2019     4265                TP13        SPOON MED M.W   20
# 95558  12/9/2019     4266           K.SRIHARI       SMART BOUL(48)    1
# 95559  12/9/2019     4267                 SMS  SMARTBOUL GLA(4000)    1
# 95560  12/9/2019     4268           ANILFANCY         RR WINEGLASS  100
# 95561  12/9/2019     4268           ANILFANCY       RR WATER GLASS  100
#
#          Rate
# 0      1690.0
# 1      1620.0
# 2        23.0
# 3      1620.0
# 4      1690.0
# ...

# %%
overral_sales_data['Qty'] = pd.to_numeric(overral_sales_data['Qty'], errors='coerce').convert_dtypes('Int64')

# %%
overral_sales_data["Qty"]= overral_sales_data["Qty"].astype('Int64')

# %%
sales_final.isnull().sum()
# Out:
# Date       0
# Voucher    0
# Party      0
# Product    0
# Qty        0
# Rate       1
# dtype: int64

# %%
overral_sales_data.isnull().sum()
# Out:
# Date       0
# Voucher    0
# Party      0
# Product    0
# Qty        0
# Rate       0
# dtype: int64

# %%
overral_sales_data.dtypes
# Out:
# Date       datetime64[us]
# Voucher             Int64
# Party                 str
# Product               str
# Qty                 Int64
# Rate              float64
# dtype: object

# %%
sales_final.dtypes
# Out:
# Date           str
# Voucher      int64
# Party          str
# Product        str
# Qty          int64
# Rate       float64
# dtype: object

# %%
overral_sales_data.shape
# Out:
# (111206, 7)

# %%
sales_final.isnull().sum()
# Out:
# Date       0
# Voucher    0
# Party      0
# Product    0
# Qty        0
# Rate       1
# dtype: int64

# %%
overral_sales_data.to_csv("overral_sales_data.csv", index=False)
