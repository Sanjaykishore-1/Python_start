# %%
import random

# %%
# Out:
# 21

# %%
def Number_guessing_game():
    import random
    
    
    print("Welcome to number guessing game")
    print("Enter your guessing number:") 
    
    secreat_number= random.randint(1,100)
    
    for i in range(1,8):
        try:
                user_input = int(input(""))
                if user_input < 1 or user_input > 100 :
                     print("enter the number between 1 - 100")
                elif user_input > secreat_number:
                     print("youre guessing is higher")
                elif user_input < secreat_number:
                     print("youre guessing is Lower")
                else:
                   print("congrats!! youre guess is correct")
                   break
        except ValueError:
            print("illvalid character, please enter valid number")
    
    if secreat_number == user_input :
        print(f"congrats!! youre guessed the number {secreat_number} in {i} attempts")
    else:
        print("sorry youre trails are exceeded")

# %%
Number_guessing_game()
# Out:
# Welcome to number guessing game
# Enter your guessing number:
#  3
# youre guessing is Lower

# %%
learner_1 ="    sanjay    "
learner_1
# Out:
# '    sanjay    '

# %%
learner_1=learner_1.strip()

# %%
learner_1.center()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 learner_1.center()
#
# TypeError: center expected at least 1 argument, got 0
