# %% [markdown]
# ## Python libraries for Data cleaning

# %%
import pandas as pd

# %%
df = pd.read_csv("data.tsv.txt", sep= "\t")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
 Item_Price = df["item_price"].str.replace('$', '')

# %%
Item_Price = pd.to_numeric(Item_Price)

# %%
df["item_price"]=Item_Price

# %%
df["total_selling_value"]
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                                   NaN        2.39
# ...

# %%
df[["item_name","item_price"]]
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
restaurant_data.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
## Question framing

# %% [markdown]
# #### Top 5 selling items of the restuarant

# %%
top_selling_items= df.groupby(by="item_name")["quantity"].sum()

# %%
top_items = top_selling_items.sort_values(ascending = False ).head()
top_items
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %%
least_items = top_selling_items.sort_values().head()
least_items
# Out:
# item_name
# Carnitas Salad                       1
# Chips and Mild Fresh Tomato Salsa    1
# Veggie Crispy Tacos                  1
# Crispy Tacos                         2
# Salad                                2
# Name: quantity, dtype: int64

# %%
## revenue of top selling items:

top_selling_items_revenue= df.groupby(by="item_name")[["quantity","item_price"]]

# %%
top_selling_items_revenue

# %%
top_selling_items_revenue.sort_values("quantity",ascending = False)
# Out:
#                                        quantity  item_price
# item_name
# Chicken Bowl                                761     7342.73
# Chicken Burrito                             591     5575.82
# Chips and Guacamole                         506     2201.04
# Steak Burrito                               386     3851.43
# Canned Soft Drink                           351      438.75
# Chips                                       230      494.34
# Steak Bowl                                  221     2260.19
# Bottled Water                               211      302.56
# Chips and Fresh Tomato Salsa                130      361.36
# Canned Soda                                 126      137.34
# Chicken Salad Bowl                          123     1228.75
# Chicken Soft Tacos                          120     1108.09
# Side of Chips                               110      185.90
# Veggie Burrito                               97      934.77
# ...
