# %% [markdown]
# # Chapter 2: Task 1

# %% [markdown]
# #### example for all functions on the data structures.

# %% [markdown]
# ## DICTIONARY

# %%
student_mark_1 = {"maths":87, "science":88, "english":79, "tamil":82, "social":79}
student_mark_1
# Out:
# {'maths': 87, 'science': 88, 'english': 79, 'tamil': 82, 'social': 79}

# %%
## clear - clear the all data

student_mark_1.clear()
student_mark_1
# Out:
# {}

# %%
## copy - copy all the content

student_mark_1 = {"maths":87, "science":88, "english":79, "tamil":82, "social":79}
student_mark_2 = student_mark_1.copy()
student_mark_2
# Out:
# {'maths': 87, 'science': 88, 'english': 79, 'tamil': 82, 'social': 79}

# %%
## fromkey - every key values on the list

student_mark_3 = dict.fromkeys(student_mark_2)
student_mark_3
# Out:
# {'maths': None,
#  'science': None,
#  'english': None,
#  'tamil': None,
#  'social': None}

# %%
## get

student_mark_1.get("student_mark_3")
student_mark_3
# Out:
# {'maths': None,
#  'science': None,
#  'english': None,
#  'tamil': None,
#  'social': None}

# %%
## items - list of items on the dictionary

student_mark_1.items()
# Out:
# dict_items([('maths', 87), ('science', 88), ('english', 79), ('tamil', 82), ('social', 79)])

# %%
## keys - shows the keys on the dictionary

student_mark_1.keys()
# Out:
# dict_keys(['maths', 'science', 'english', 'tamil', 'social'])

# %%
## pop - shows the specific value on the key

student_mark_1.pop('science')
# Out:
# 88

# %%
## popitem - random select on the list

student_mark_1.popitem()
# Out:
# ('tamil', 82)

# %%
## setdefault

student_mark_1.setdefault(0)
student_mark_1
# Out:
# {'maths': 87, 'english': 79, 0: None}

# %%
## 
student_mark_1 = {"maths":87, "science":88, "english":79, "tamil":82, "social":79}
student_mark_4 = {"maths":90, "science":88, "english":79, "tamil":82, "economics":79}
student_mark_1.update(student_mark_4)
student_mark_4
# Out:
# {'maths': 90, 'science': 88, 'english': 79, 'tamil': 82, 'economics': 79}

# %%
## values - shows the values on the dictionary

student_mark_1.values()
# Out:
# dict_values([90, 88, 79, 82, 79, 79])

# %% [markdown]
# ## SET

# %%
Tamil_marks = {"79","45","67","98","35"}

# %%
type(Tamil_marks)
# Out:
# set

# %%
## add - adding the value

Tamil_marks.add(55)
Tamil_marks
# Out:
# {'35', '45', 55, '67', '79', '98'}

# %%
## clear the value

Tamil_marks.clear()
Tamil_marks
# Out:
# set()

# %%
Tamil_marks = {"79","45","67","98","35"}

# %%
## copy - copy the values

CS_marks = Tamil_marks.copy()
CS_marks
# Out:
# {'35', '45', '67', '79', '98'}

# %%
## difference between the to variables

Tamil_marks.difference(CS_marks)
# Out:
# set()

# %%
## difference update

Tamil_marks.difference_update(CS_marks)
Tamil_marks
# Out:
# set()

# %%
Tamil_marks = {"79","45","67","98","35"}

# %%
Accounts_marks = {"47","45","67","90","40"}

# %%
## discard 

Tamil_marks.discard(79)
Tamil_marks
# Out:
# {'35', '45', '67', '79', '98'}

# %%
## intersection - intersecting the same values on both variables

Tamil_marks.intersection(Accounts_marks)
# Out:
# {'45', '67'}

# %%
## intersection update

Tamil_marks.intersection_update(Accounts_marks)

# %%
## isdisjoint - identify the common elements - true if no common elemets

Tamil_marks.isdisjoint(Accounts_marks)
# Out:
# False

# %%
## issubset identify the common elements - true if common elemets

Tamil_marks.issubset(Accounts_marks)
# Out:
# True

# %%
maths_marks_1 = {"85","45","80","98","22"}

# %%
science_marks= maths_marks.copy()

# %%
## issuperset - true if all elements are same 

Tamil_marks.issuperset(science_marks)
# Out:
# False

# %%
## pop a random item and removes and return to original list

Tamil_marks = {"79","45","67","98","35"}
Tamil_marks.pop()
# Out:
# '98'

# %%
Tamil_marks
# Out:
# {'35', '45', '67', '79'}

# %%
## remove - any value on the variable if wanted

Tamil_marks = {"79","45","67","98","35"}
Tamil_marks.remove("79")
Tamil_marks
# Out:
# {'35', '45', '67', '98'}

# %%
## symmetric - shows the non common values as output

Tamil_marks.symmetric_difference(maths_marks_1)
# Out:
# {'22', '35', '67', '79', '80', '85', '98'}

# %%
## symmetric_

Tamil_marks.symmetric_difference_update(maths_marks_1)
Tamil_marks
# Out:
# {'(', ')', '0', '22', '35', '6', '67', '79', '80', '85', '9', '98'}

# %%
## union - shows on order when common numbers may show once on the 

Tamil_marks.union(maths_marks_1)
# Out:
# {'(', ')', '0', '22', '35', '45', '6', '67', '79', '80', '85', '9', '98'}

# %%
## update - update on the original value

Tamil_marks.update()
Tamil_marks
# Out:
# {'(', ')', '0', '35', '45', '6', '67', '79', '9'}

# %% [markdown]
# ## TUPLE

# %%
English_marks = (79,45,67,98,35)

# %%
type(English_marks)
# Out:
# tuple

# %%
## COUNT - counting the value occur

English_marks.count(45)
# Out:
# 1

# %%
## INDEX - positining 

English_marks.index(45)
# Out:
# 1

# %% [markdown]
# ## LIST

# %%
maths_marks = [79,45,67,98,35]
type(maths_marks)
# Out:
# list

# %%
##append  -  adiing the new value on the list

maths_marks.append(88)
maths_marks
# Out:
# [79, 45, 67, 98, 35, 88]

# %%
##clear - clear the whole values

maths_marks.clear()
maths_marks
# Out:
# []

# %%
maths_marks = [79,45,67,98,35]

# %%
##copy - copy the whole values

science_marks= maths_marks.copy()
science_marks
# Out:
# [79, 45, 67, 98, 35]

# %%
##count - counting the number of times written

maths_marks.count(98)
# Out:
# 1

# %%
## extend --- extending with another variable

maths_marks.extend(science_marks)
maths_marks
# Out:
# [79, 45, 67, 98, 35, 79, 45, 67, 98, 35]

# %%
##index  --- positioning

maths_marks.index(35)
# Out:
# 4

# %%
## insert - (1:position, 2:value)

maths_marks.insert(2,76)
maths_marks
# Out:
# [79, 45, 76, 67, 98, 35, 79, 45, 67, 98, 35]

# %%
## pop - removing the specific value with index position

maths_marks.pop(3)
# Out:
# 67

# %%
maths_marks
# Out:
# [79, 45, 76, 98, 35, 79, 45, 67, 98, 35]

# %%
## remove - removing the specific value in the list 

maths_marks.remove(76)
maths_marks
# Out:
# [79, 45, 98, 35, 79, 45, 67, 98, 35]

# %%
## reverse - reversing the whole list

maths_marks.reverse()
maths_marks
# Out:
# [35, 98, 67, 45, 79, 35, 98, 45, 79]

# %%
#sort - sorting in order wise

maths_marks.sort()
maths_marks
# Out:
# [35, 35, 45, 45, 67, 79, 79, 98, 98]
